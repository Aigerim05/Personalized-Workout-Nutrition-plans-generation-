# %%
import pandas as pd
from functions import create_user_features
from functions import predict_cluster_id

pd.set_option('display.max_columns', None)

# Dataset with clusters 
DATA_PATH = "data/dataset_with_clusters.csv"
NEW_USER = "data/new_user.csv"

# %%
df = pd.read_csv(DATA_PATH)
print(df.shape)
df.head(3)
# Out:
# (19823, 37)
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   35    Male        65.27        1.62   188.58   157.65        69.05
# 1   23  Female        56.41        1.55   179.43   131.75        73.18
# 2   33  Female        58.98        1.67   175.04   123.95        54.96
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  \
# 0                      1.00          1080.90     Strength
# 1                      1.37          1809.91         HIIT
# 2                      0.91           802.26       Cardio
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 0                   1.50                              4                 2
# 1                   1.90                              4                 2
# 2                   1.88                              3                 1
#
#      BMI  Daily meals frequency  Calories  sugar_g  serving_size_g  rating  \
# 0  24.87                      3    1806.0    31.77          120.47    1.31
# 1  23.48                      3    1577.0    12.34          109.15    1.92
# 2  21.15                      2    1608.0    42.81          399.43    4.70
#
#    Name of Exercise  Sets  Reps                               Benefit  \
# 0  Decline Push-ups     5    21  Improves shoulder health and posture
# 1       Bear Crawls     4    16                 Strengthens lower abs
# 2              Dips     5    22                 Builds chest strength
#
#    Burns Calories (per 30 min)    Target Muscle Group Equipment Needed  \
# 0                       342.58     Shoulders, Triceps    Cable Machine
# 1                       357.16  Back, Core, Shoulders      Step or Box
# 2                       359.63     Quadriceps, Glutes      Step or Box
#
#    Difficulty Level Body Part Type of Muscle               Workout  sodium_g  \
# 0                 3      Legs           Lats        Dumbbell flyes   1.72994
# 1                 2     Chest           Lats        Lateral raises   0.69308
# 2                 2      Arms  Grip Strength  Standing calf raises   2.14248
#
#    cholesterol_g   Carbs  Proteins   Fats               meal_name  cluster_id
# 0        0.28505  267.68    106.05  71.63     Grilled Vegan Lunch           2
# 1        0.30061  214.32     85.41  56.97  Fried Vegetarian Lunch           2
# 2        0.21542  246.04     98.11  65.48  Boiled Paleo Breakfast           1

# %%
new_user = pd.read_csv(NEW_USER)
new_user
# Out:
#    Age  Gender  Weight (kg)  Height (m)        BMI  Experience_Level  \
# 0   33  Female         55.0         1.7  19.031142                 1
#
#    Workout_Frequency (days/week)  Daily meals frequency diet_type  Goal  \
# 0                              1                      1  Balanced  Loss
#
#    WeightChange (kg)  GoalDays
# 0                1.0        10

# %%
df = create_user_features(df, new_user)
print(df.shape)
df.sample(3)
# Out:
# (19823, 45)
#        Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 4751    53    Male        72.70        1.76   169.03   151.46        70.09
# 2604    56  Female        44.73        1.73   164.82   129.20        73.26
# 13574   21  Female        61.15        1.57   190.99   152.21        64.29
#
#        Session_Duration (hours)  Calories_Burned Workout_Type  \
# 4751                       1.08           777.60         Yoga
# 2604                       0.84          1014.55         HIIT
# 13574                      1.94          2017.60       Cardio
#
#        Water_Intake (liters)  Experience_Level    BMI  Daily meals frequency  \
# 4751                    2.82                 2  23.47                      3
# 2604                    2.60                 1  14.95                      3
# 13574                   2.74                 3  24.81                      3
#
#        Calories  sugar_g  serving_size_g  rating Name of Exercise  Sets  Reps  \
# 4751     1814.0     4.13          153.14    1.91    Renegade Rows     5    24
# 2604     1331.0    32.30          115.57    1.91            Plank     4    19
# 13574    1691.0     4.02          197.78    1.22        Deadlifts     5    24
#
#                                              Benefit  \
# 4751   Enhances full-body coordination and stability
# 2604                             Targets lower chest
# 13574                           Improves flexibility
#
#        Burns Calories (per 30 min) Target Muscle Group   Equipment Needed  \
# 4751                        371.48  Lower Back, Glutes  None or Dumbbells
# 2604                        362.02           Shoulders        Step or Box
# 13574                       336.98      Triceps, Chest        Pull-up Bar
#
#        Difficulty Level Body Part   Type of Muscle  \
# 4751                  1       Abs        Posterior
# 2604                  1      Back  Wrist Extensors
# 13574                 3      Arms            Quads
#
#                            Workout  sodium_g  cholesterol_g   Carbs  Proteins  \
# 4751                    Face pulls   0.81015        0.20026  281.67    112.52
# 2604   Overhead triceps extensions   2.27351        0.16812  302.67    121.26
# 13574            Seated cable rows   1.93157        0.21772  245.80     98.27
#
#         Fats                  meal_name  cluster_id      BMR    PAL  \
# 4751   74.90  Roasted Vegetarian Dinner           1  1567.00  1.375
# 2604   81.43            Raw Vegan Snack           1  1087.55  1.375
# 13574  65.87        Boiled Vegan Dinner           2  1326.75  1.375
#
#              TDEE  CalorieChange  CaloriesToBurnTraining  \
# 4751   2154.62500         7700.0                  3850.0
# 2604   1495.38125         7700.0                  3850.0
# 13574  1824.28125         7700.0                  3850.0
#
#        CaloriesReducedFromFood  CaloriesPerDay  TotalWorkouts  \
# 4751                    3850.0      1769.62500       1.428571
# 2604                    3850.0      1110.38125       1.428571
# 13574                   3850.0      1439.28125       1.428571
#
#        CaloriesPerWorkout
# 4751               2695.0
# 2604               2695.0
# 13574              2695.0

# %%
df.to_csv('data/dataset_with_user_features.csv', index=False)
