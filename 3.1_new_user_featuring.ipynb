# %%
import pandas as pd
from functions import create_user_features
from functions import predict_cluster_id

pd.set_option('display.max_columns', None)

# Dataset with clusters 
DATA_PATH = "data/dataset_with_clusters.csv"
NEW_USER = "data/new_user.csv"

# %%
df = pd.read_csv(DATA_PATH)
print(df.shape)
df.head(3)
# Out:
# (19823, 39)
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   35    Male        65.27        1.62   188.58   157.65        69.05
# 1   23  Female        56.41        1.55   179.43   131.75        73.18
# 2   33  Female        58.98        1.67   175.04   123.95        54.96
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  \
# 0                      1.00          1080.90     Strength
# 1                      1.37          1809.91         HIIT
# 2                      0.91           802.26       Cardio
#
#    Water_Intake (liters)  Workout_Frequency (days)  Experience_Level    BMI  \
# 0                   1.50                         4                 2  24.87
# 1                   1.90                         4                 2  23.48
# 2                   1.88                         3                 1  21.15
#
#    Daily meals frequency  Calories  meal_type   diet_type  sugar_g  \
# 0                      3    1806.0      Lunch       Vegan    31.77
# 1                      3    1577.0      Lunch  Vegetarian    12.34
# 2                      2    1608.0  Breakfast       Paleo    42.81
#
#    serving_size_g cooking_method  rating  Name of Exercise  Sets  Reps  \
# 0          120.47        Grilled    1.31  Decline Push-ups     5    21
# 1          109.15          Fried    1.92       Bear Crawls     4    16
# 2          399.43         Boiled    4.70              Dips     5    22
#
#                                 Benefit  Burns Calories (per 30 min)  \
# 0  Improves shoulder health and posture                       342.58
# 1                 Strengthens lower abs                       357.16
# 2                 Builds chest strength                       359.63
#
#      Target Muscle Group Equipment Needed  Difficulty Level Body Part  \
# 0     Shoulders, Triceps    Cable Machine                 3      Legs
# 1  Back, Core, Shoulders      Step or Box                 2     Chest
# 2     Quadriceps, Glutes      Step or Box                 2      Arms
#
#   Type of Muscle               Workout  sodium_g  cholesterol_g   Carbs  \
# 0           Lats        Dumbbell flyes   1.72994        0.28505  267.68
# 1           Lats        Lateral raises   0.69308        0.30061  214.32
# 2  Grip Strength  Standing calf raises   2.14248        0.21542  246.04
#
#    Proteins   Fats  cluster_id
# 0    106.05  71.63           2
# 1     85.41  56.97           2
# 2     98.11  65.48           1

# %%
new_user = pd.read_csv(NEW_USER)
new_user
# Out:
#    Age Gender  Weight (kg)  Height (m)        BMI  Experience_Level  \
# 0   22   Male         88.0         1.8  27.160494                 2
#
#    Workout_Frequency (days)  Daily meals frequency diet_type      Goal  \
# 0                         3                      3      Keto  Maintain
#
#    WeightChange (kg)  GoalDays  cluster_id     BMR    PAL    TDEE  \
# 0                3.0        30           0  1900.0  1.725  3277.5
#
#    CalorieChange  CaloriesToBurnTraining  CaloriesReducedFromFood  \
# 0        23100.0                 11550.0                  11550.0
#
#    CaloriesPerDay  TotalWorkouts  CaloriesPerWorkout
# 0          3277.5      12.857143          898.333333

# %%
df = create_user_features(df, new_user)
print(df.shape)
df.sample(3)
# Out:
# (19823, 47)
#        Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 16902   47  Female        41.14        1.58   160.05   163.23        68.15
# 2305    43  Female        42.28        1.64   162.16   147.83        58.88
# 14914   43    Male        46.54        1.63   175.96   139.10        65.06
#
#        Session_Duration (hours)  Calories_Burned Workout_Type  \
# 16902                      1.03           742.22         Yoga
# 2305                       1.33           957.60         Yoga
# 14914                      1.18          1427.80         HIIT
#
#        Workout_Frequency (days)  Experience_Level    BMI  \
# 16902                         4                 2  16.48
# 2305                          3                 2  15.72
# 14914                         2                 1  17.52
#
#        Daily meals frequency  Calories  meal_type diet_type  sugar_g  \
# 16902                      2    1173.0  Breakfast  Balanced     9.76
# 2305                       3    1278.0      Lunch  Balanced    43.45
# 14914                      3    1324.0  Breakfast     Paleo    19.06
#
#        serving_size_g cooking_method  rating     Name of Exercise  Sets  Reps  \
# 16902          489.46        Roasted    2.26       Reverse Lunges     4    16
# 2305           145.93          Fried    3.22     Bicycle Crunches     4    18
# 14914          264.44          Baked    4.39  Plyometric Push-ups     5    19
#
#                                   Benefit  Burns Calories (per 30 min)  \
# 16902               Builds shoulder width                       361.12
# 2305         Improves lower back strength                       340.63
# 14914  Improves back strength and posture                       348.09
#
#           Target Muscle Group        Equipment Needed  Difficulty Level  \
# 16902   Core, Shoulders, Legs          Bench or Chair                 2
# 2305   Lower Abs, Hip Flexors  Parallel Bars or Chair                 1
# 14914               Shoulders    Dumbbells or Barbell                 3
#
#       Body Part Type of Muscle           Workout  sodium_g  cholesterol_g  \
# 16902      Legs  Wrist Flexors      Triceps dips   0.19739        0.23582
# 2305       Legs       Anterior  Bicycle crunches   2.17811        0.01680
# 14914      Legs           Lats         Leg curls   2.12395        0.15117
#
#         Carbs  Proteins   Fats  cluster_id      BMR    PAL        TDEE  \
# 16902  194.62     78.08  52.56           2  1002.90  1.725  1730.00250
# 2305   256.16    103.23  68.52           1  1071.80  1.725  1848.85500
# 14914  234.01     93.15  62.05           1  1274.15  1.725  2197.90875
#
#        CalorieChange  CaloriesToBurnTraining  CaloriesReducedFromFood  \
# 16902        23100.0                 11550.0                  11550.0
# 2305         23100.0                 11550.0                  11550.0
# 14914        23100.0                 11550.0                  11550.0
#
#        CaloriesPerDay  TotalWorkouts  CaloriesPerWorkout
# 16902      1730.00250      12.857143          898.333333
# 2305       1848.85500      12.857143          898.333333
# 14914      2197.90875      12.857143          898.333333

# %%
df.to_csv('data/dataset_with_user_features.csv', index=False)
