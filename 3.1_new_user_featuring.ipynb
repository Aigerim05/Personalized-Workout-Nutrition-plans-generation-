# %%
import pandas as pd
from functions import create_user_features
from functions import predict_cluster_id
import importlib
import functions

importlib.reload(functions)

pd.set_option('display.max_columns', None)

# Dataset with clusters 
DATA_PATH = "data/dataset_with_clusters.csv"
NEW_USER = "data/new_user.csv"

# %%
df = pd.read_csv(DATA_PATH)
print(df.shape)
df.head(3)
# Out:
# (19823, 39)
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   35    Male        65.27        1.62   188.58   157.65        69.05
# 1   23  Female        56.41        1.55   179.43   131.75        73.18
# 2   33  Female        58.98        1.67   175.04   123.95        54.96
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  \
# 0                      1.00          1080.90     Strength
# 1                      1.37          1809.91         HIIT
# 2                      0.91           802.26       Cardio
#
#    Water_Intake (liters)  Workout_Frequency (days)  Experience_Level    BMI  \
# 0                   1.50                         4                 2  24.87
# 1                   1.90                         4                 2  23.48
# 2                   1.88                         3                 1  21.15
#
#    Daily meals frequency  Calories  meal_type   diet_type  sugar_g  \
# 0                      3    1806.0      Lunch       Vegan    31.77
# 1                      3    1577.0      Lunch  Vegetarian    12.34
# 2                      2    1608.0  Breakfast       Paleo    42.81
#
#    serving_size_g cooking_method  rating  Name of Exercise  Sets  Reps  \
# 0          120.47        Grilled    1.31  Decline Push-ups     5    21
# 1          109.15          Fried    1.92       Bear Crawls     4    16
# 2          399.43         Boiled    4.70              Dips     5    22
#
#                                 Benefit  Burns Calories (per 30 min)  \
# 0  Improves shoulder health and posture                       342.58
# 1                 Strengthens lower abs                       357.16
# 2                 Builds chest strength                       359.63
#
#      Target Muscle Group Equipment Needed  Difficulty Level Body Part  \
# 0     Shoulders, Triceps    Cable Machine                 3      Legs
# 1  Back, Core, Shoulders      Step or Box                 2     Chest
# 2     Quadriceps, Glutes      Step or Box                 2      Arms
#
#   Type of Muscle               Workout  sodium_g  cholesterol_g   Carbs  \
# 0           Lats        Dumbbell flyes   1.72994        0.28505  267.68
# 1           Lats        Lateral raises   0.69308        0.30061  214.32
# 2  Grip Strength  Standing calf raises   2.14248        0.21542  246.04
#
#    Proteins   Fats  cluster_id
# 0    106.05  71.63           2
# 1     85.41  56.97           2
# 2     98.11  65.48           1

# %%
new_user = pd.read_csv(NEW_USER)
new_user
# Out:
#    Age  Gender  Weight (kg)  Height (m)        BMI  Experience_Level  \
# 0   44  Female         77.0         1.7  26.643599                 1
#
#    Workout_Frequency (days)  Daily meals frequency   diet_type  Goal  \
# 0                         2                      2  Vegetarian  Loss
#
#    WeightChange (kg)  GoalDays  cluster_id     BMR   PAL      TDEE  \
# 0                6.0        30           1  1451.5  1.55  2249.825
#
#    CalorieChange  CaloriesToBurnTraining  CaloriesReducedFromFood  \
# 0        46200.0                 23100.0                  23100.0
#
#    CaloriesPerDay  TotalWorkouts  CaloriesPerWorkout
# 0        1479.825       8.571429              2695.0

# %%
df = create_user_features(df, new_user)
print(df.shape)
df.sample(3)
# Out:
# (19823, 48)
#        Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 10295   32    Male        62.90        1.63   190.11   161.03        57.79
# 15407   39    Male        64.36        1.69   189.99   147.98        57.82
# 9910    34  Female        75.11        1.57   177.93   158.31        51.96
#
#        Session_Duration (hours)  Calories_Burned Workout_Type  \
# 10295                      1.67          1739.47       Cardio
# 15407                      1.25          1650.00         HIIT
# 9910                       1.47           971.08         Yoga
#
#        Water_Intake (liters)  Workout_Frequency (days)  Experience_Level  \
# 10295                    2.7                         5                 3
# 15407                    1.9                         4                 2
# 9910                     2.4                         3                 1
#
#          BMI  Daily meals frequency  Calories meal_type diet_type  sugar_g  \
# 10295  23.67                      3    1707.0     Lunch      Keto    35.61
# 15407  22.53                      3    1974.0    Dinner     Paleo    46.92
# 9910   30.47                      3    2034.0    Dinner  Low-Carb    30.45
#
#        serving_size_g cooking_method  rating   Name of Exercise  Sets  Reps  \
# 10295          318.38        Steamed    2.99         Frog Jumps     4    19
# 15407          487.72          Baked    2.90  Windshield Wipers     3    12
# 9910           164.04        Roasted    2.91        Tricep Dips     4    25
#
#                                       Benefit  Burns Calories (per 30 min)  \
# 10295  Improves shoulder mobility and posture                       330.01
# 15407    Improves shoulder health and posture                       250.19
# 9910         Activates and strengthens glutes                       357.28
#
#          Target Muscle Group                  Equipment Needed  \
# 10295  Back, Core, Shoulders  Cable Machine or Resistance Band
# 15407         Triceps, Chest                    Bench or Chair
# 9910      Glutes, Hamstrings                        Kettlebell
#
#        Difficulty Level  Body Part Type of Muscle                 Workout  \
# 10295                 1  Shoulders    Lower Chest             Bicep Curls
# 15407                 1       Back    Lower Chest  Incline dumbbell press
# 9910                  1      Chest        Triceps                Crunches
#
#        sodium_g  cholesterol_g   Carbs  Proteins   Fats  cluster_id      BMR  \
# 10295   1.44432        0.15928  218.17     87.41  58.24           2  1492.75
# 15407   1.04973        0.08906  308.90    124.25  82.56           2  1509.85
# 9910    0.10196        0.10709  278.21    112.34  74.65           1  1401.35
#
#         PAL       TDEE  CalorieChange  CaloriesToBurnTraining  \
# 10295  1.55  2313.7625        46200.0                 23100.0
# 15407  1.55  2340.2675        46200.0                 23100.0
# 9910   1.55  2172.0925        46200.0                 23100.0
#
#        CaloriesReducedFromFood  CaloriesPerDay  TotalWorkouts  \
# 10295                  23100.0       1543.7625       8.571429
# 15407                  23100.0       1570.2675       8.571429
# 9910                   23100.0       1402.0925       8.571429
#
#        CaloriesPerWorkout
# 10295              2695.0
# 15407              2695.0
# 9910               2695.0

# %%
df.to_csv('data/dataset_with_user_features.csv', index=False)
