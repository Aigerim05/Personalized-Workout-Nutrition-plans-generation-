# %%
import pandas as pd
from functions import create_workout_features

pd.set_option('display.max_columns', None)

# Preprocessed original file without scaling 
DATA_PATH = "data/dataset_with_user_features.csv"

# %%
df = pd.read_csv(DATA_PATH)
print(df.shape)
df.head(3)
# Out:
# (19823, 45)
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   35    Male        65.27        1.62   188.58   157.65        69.05
# 1   23  Female        56.41        1.55   179.43   131.75        73.18
# 2   33  Female        58.98        1.67   175.04   123.95        54.96
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  \
# 0                      1.00          1080.90     Strength
# 1                      1.37          1809.91         HIIT
# 2                      0.91           802.26       Cardio
#
#    Water_Intake (liters)  Experience_Level    BMI  Daily meals frequency  \
# 0                   1.50                 2  24.87                      3
# 1                   1.90                 2  23.48                      3
# 2                   1.88                 1  21.15                      2
#
#    Calories  sugar_g  serving_size_g  rating  Name of Exercise  Sets  Reps  \
# 0    1806.0    31.77          120.47    1.31  Decline Push-ups     5    21
# 1    1577.0    12.34          109.15    1.92       Bear Crawls     4    16
# 2    1608.0    42.81          399.43    4.70              Dips     5    22
#
#                                 Benefit  Burns Calories (per 30 min)  \
# 0  Improves shoulder health and posture                       342.58
# 1                 Strengthens lower abs                       357.16
# 2                 Builds chest strength                       359.63
#
#      Target Muscle Group Equipment Needed  Difficulty Level Body Part  \
# 0     Shoulders, Triceps    Cable Machine                 3      Legs
# 1  Back, Core, Shoulders      Step or Box                 2     Chest
# 2     Quadriceps, Glutes      Step or Box                 2      Arms
#
#   Type of Muscle               Workout  sodium_g  cholesterol_g   Carbs  \
# 0           Lats        Dumbbell flyes   1.72994        0.28505  267.68
# 1           Lats        Lateral raises   0.69308        0.30061  214.32
# 2  Grip Strength  Standing calf raises   2.14248        0.21542  246.04
#
#    Proteins   Fats               meal_name  cluster_id      BMR    PAL  \
# 0    106.05  71.63     Grilled Vegan Lunch           2  1495.20  1.375
# 1     85.41  56.97  Fried Vegetarian Lunch           2  1256.85  1.375
# 2     98.11  65.48  Boiled Paleo Breakfast           1  1307.55  1.375
#
#          TDEE  CalorieChange  CaloriesToBurnTraining  CaloriesReducedFromFood  \
# 0  2055.90000         7700.0                  3850.0                   3850.0
# 1  1728.16875         7700.0                  3850.0                   3850.0
# 2  1797.88125         7700.0                  3850.0                   3850.0
#
#    CaloriesPerDay  TotalWorkouts  CaloriesPerWorkout
# 0      1670.90000       1.428571              2695.0
# 1      1343.16875       1.428571              2695.0
# 2      1412.88125       1.428571              2695.0

# %%
df = create_workout_features(df)
df.head(3)
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   35    Male        65.27        1.62   188.58   157.65        69.05
# 1   23  Female        56.41        1.55   179.43   131.75        73.18
# 2   33  Female        58.98        1.67   175.04   123.95        54.96
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  \
# 0                      1.00          1080.90     Strength
# 1                      1.37          1809.91         HIIT
# 2                      0.91           802.26       Cardio
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 0                   1.50                              4                 2
# 1                   1.90                              4                 2
# 2                   1.88                              3                 1
#
#      BMI  Daily meals frequency  Calories  sugar_g  serving_size_g  rating  \
# 0  24.87                      3    1806.0    31.77          120.47    1.31
# 1  23.48                      3    1577.0    12.34          109.15    1.92
# 2  21.15                      2    1608.0    42.81          399.43    4.70
#
#    Name of Exercise  Sets  Reps                               Benefit  \
# 0  Decline Push-ups     5    21  Improves shoulder health and posture
# 1       Bear Crawls     4    16                 Strengthens lower abs
# 2              Dips     5    22                 Builds chest strength
#
#    Burns Calories (per 30 min)    Target Muscle Group Equipment Needed  \
# 0                       342.58     Shoulders, Triceps    Cable Machine
# 1                       357.16  Back, Core, Shoulders      Step or Box
# 2                       359.63     Quadriceps, Glutes      Step or Box
#
#    Difficulty Level Body Part Type of Muscle               Workout  sodium_g  \
# 0                 3      Legs           Lats        Dumbbell flyes   1.72994
# 1                 2     Chest           Lats        Lateral raises   0.69308
# 2                 2      Arms  Grip Strength  Standing calf raises   2.14248
#
#    cholesterol_g   Carbs  Proteins   Fats               meal_name      BMR  \
# 0        0.28505  267.68    106.05  71.63     Grilled Vegan Lunch  1495.20
# 1        0.30061  214.32     85.41  56.97  Fried Vegetarian Lunch  1256.85
# 2        0.21542  246.04     98.11  65.48  Boiled Paleo Breakfast  1307.55
#
#      PAL        TDEE  cluster_id     E_raw     E_eff         E   pct_HRR  \
# 0  1.900  2840.88000           2  0.295123  0.845312  0.570217  0.741237
# 1  1.900  2388.01500           2  0.579037  0.902949  0.740993  0.551247
# 2  1.725  2255.52375           1  0.186606  0.912713  0.549660  0.574534
#
#           I  workload         S  Duration_min         D   pen_age   pen_bmi  \
# 0  0.526466       105  0.250000          60.0  0.333333  0.404762  0.335952
# 1  0.256055        64  0.225000          82.2  0.575163  0.119048  0.299555
# 2  0.289199       110  0.416667          54.6  0.274510  0.357143  0.238544
#
#    pen_hrr  pen_skill         R
# 0      0.0          1  0.637310
# 1      0.0          0  0.862514
# 2      0.0          1  0.685580

# %%
df.to_csv('data/dataset_workout.csv', index=False)
