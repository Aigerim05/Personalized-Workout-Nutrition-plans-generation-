# %%
import pandas as pd
from functions import create_meal_features

pd.set_option('display.max_columns', None)

# Preprocessed original file without scaling 
DATA_PATH = "data/dataset_with_user_features.csv"
NEW_USER = "data/new_user.csv"

# %%
df = pd.read_csv(DATA_PATH)
print(df.shape)
df.head(3)
# Out:
# (19823, 47)
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   35    Male        65.27        1.62   188.58   157.65        69.05
# 1   23  Female        56.41        1.55   179.43   131.75        73.18
# 2   33  Female        58.98        1.67   175.04   123.95        54.96
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  \
# 0                      1.00          1080.90     Strength
# 1                      1.37          1809.91         HIIT
# 2                      0.91           802.26       Cardio
#
#    Workout_Frequency (days)  Experience_Level    BMI  Daily meals frequency  \
# 0                         4                 2  24.87                      3
# 1                         4                 2  23.48                      3
# 2                         3                 1  21.15                      2
#
#    Calories  meal_type   diet_type  sugar_g  serving_size_g cooking_method  \
# 0    1806.0      Lunch       Vegan    31.77          120.47        Grilled
# 1    1577.0      Lunch  Vegetarian    12.34          109.15          Fried
# 2    1608.0  Breakfast       Paleo    42.81          399.43         Boiled
#
#    rating  Name of Exercise  Sets  Reps                               Benefit  \
# 0    1.31  Decline Push-ups     5    21  Improves shoulder health and posture
# 1    1.92       Bear Crawls     4    16                 Strengthens lower abs
# 2    4.70              Dips     5    22                 Builds chest strength
#
#    Burns Calories (per 30 min)    Target Muscle Group Equipment Needed  \
# 0                       342.58     Shoulders, Triceps    Cable Machine
# 1                       357.16  Back, Core, Shoulders      Step or Box
# 2                       359.63     Quadriceps, Glutes      Step or Box
#
#    Difficulty Level Body Part Type of Muscle               Workout  sodium_g  \
# 0                 3      Legs           Lats        Dumbbell flyes   1.72994
# 1                 2     Chest           Lats        Lateral raises   0.69308
# 2                 2      Arms  Grip Strength  Standing calf raises   2.14248
#
#    cholesterol_g   Carbs  Proteins   Fats  cluster_id      BMR    PAL  \
# 0        0.28505  267.68    106.05  71.63           2  1495.20  1.725
# 1        0.30061  214.32     85.41  56.97           2  1256.85  1.725
# 2        0.21542  246.04     98.11  65.48           1  1307.55  1.725
#
#          TDEE  CalorieChange  CaloriesToBurnTraining  CaloriesReducedFromFood  \
# 0  2579.22000        23100.0                 11550.0                  11550.0
# 1  2168.06625        23100.0                 11550.0                  11550.0
# 2  2255.52375        23100.0                 11550.0                  11550.0
#
#    CaloriesPerDay  TotalWorkouts  CaloriesPerWorkout
# 0      2579.22000      12.857143          898.333333
# 1      2168.06625      12.857143          898.333333
# 2      2255.52375      12.857143          898.333333

# %%
new_user = pd.read_csv(NEW_USER)
new_user
# Out:
#    Age Gender  Weight (kg)  Height (m)        BMI  Experience_Level  \
# 0   22   Male         88.0         1.8  27.160494                 2
#
#    Workout_Frequency (days)  Daily meals frequency diet_type      Goal  \
# 0                         3                      3      Keto  Maintain
#
#    WeightChange (kg)  GoalDays  cluster_id     BMR    PAL    TDEE  \
# 0                3.0        30           0  1900.0  1.725  3277.5
#
#    CalorieChange  CaloriesToBurnTraining  CaloriesReducedFromFood  \
# 0        23100.0                 11550.0                  11550.0
#
#    CaloriesPerDay  TotalWorkouts  CaloriesPerWorkout
# 0          3277.5      12.857143          898.333333

# %%
df = create_meal_features(df, new_user)
df.head(3)
# Out:
#    Age  Gender  Max_BPM  Avg_BPM  Resting_BPM  Session_Duration (hours)  \
# 0   35    Male   188.58   157.65        69.05                      1.00
# 1   23  Female   179.43   131.75        73.18                      1.37
# 2   33  Female   175.04   123.95        54.96                      0.91
#
#   Workout_Type  Experience_Level  rating  Name of Exercise  Sets  Reps  \
# 0     Strength                 2    1.31  Decline Push-ups     5    21
# 1         HIIT                 2    1.92       Bear Crawls     4    16
# 2       Cardio                 1    4.70              Dips     5    22
#
#                                 Benefit  Burns Calories (per 30 min)  \
# 0  Improves shoulder health and posture                       342.58
# 1                 Strengthens lower abs                       357.16
# 2                 Builds chest strength                       359.63
#
#      Target Muscle Group Equipment Needed  Difficulty Level Body Part  \
# 0     Shoulders, Triceps    Cable Machine                 3      Legs
# 1  Back, Core, Shoulders      Step or Box                 2     Chest
# 2     Quadriceps, Glutes      Step or Box                 2      Arms
#
#   Type of Muscle               Workout  cluster_id               meal_name  \
# 0           Lats        Dumbbell flyes           2     Grilled Vegan Lunch
# 1           Lats        Lateral raises           2  Fried Vegetarian Lunch
# 2  Grip Strength  Standing calf raises           1  Boiled Paleo Breakfast
#
#           C         P         M        ED         F
# 0  0.551030  0.342572  0.995365  0.258372  0.173291
# 1  0.481159  0.211067  0.998265  0.247696  0.471934
# 2  0.490618  0.604530  0.998705  0.082439  0.096575

# %%
df.to_csv('data/dataset_meal.csv', index=False)
